# %% [markdown]
# ### Models Integration with OpenAI,, Google Gemini and GROQ

# %%
import os
from dotenv import load_dotenv
load_dotenv()

os.environ["GROQ_API_KEY"]=os.getenv("GROQ_API_KEY")
os.environ["OPENAI_API_KEY"]=os.getenv("OPENAI_API_KEY")
os.environ["GOOGLE_API_KEY"]=os.getenv("GOOGLE_API_KEY")

# %%
from langchain.chat_models import init_chat_model
model=init_chat_model("groq:llama-3.3-70b-versatile")
model
# Out:
# ChatGroq(output_version=None, profile={'name': 'Llama 3.3 70B Versatile', 'release_date': '2024-12-06', 'last_updated': '2024-12-06', 'open_weights': True, 'max_input_tokens': 131072, 'max_output_tokens': 32768, 'text_inputs': True, 'image_inputs': False, 'audio_inputs': False, 'video_inputs': False, 'text_outputs': True, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': False, 'tool_calling': True, 'attachment': False, 'temperature': True}, client=<groq.resources.chat.completions.Completions object at 0x115217890>, async_client=<groq.resources.chat.completions.AsyncCompletions object at 0x11531c2d0>, model_name='llama-3.3-70b-versatile', model_kwargs={}, groq_api_key=SecretStr('**********'), groq_api_base=None, groq_proxy=None)

# %%
## invoke the model 
response=model.invoke("Hello how are you?")
response
# Out:
# AIMessage(content="Hello! I'm just a language model, so I don't have feelings or emotions like humans do, but I'm functioning properly and ready to help with any questions or tasks you may have. How about you? How's your day going so far?", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 52, 'prompt_tokens': 40, 'total_tokens': 92, 'completion_time': 0.130709233, 'completion_tokens_details': None, 'prompt_time': 0.003276685, 'prompt_tokens_details': None, 'queue_time': 0.051556492, 'total_time': 0.133985918}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_dae98b5ecb', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019eb131-de2e-78f3-99cd-c7ba53cca513-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 40, 'output_tokens': 52, 'total_tokens': 92})

# %%
### chatopenai 
from langchain_groq import ChatGroq
model=ChatGroq(model="llama-3.3-70b-versatile") 
response=model.invoke("hello, how are you?")
response
# Out:
# AIMessage(content="Hello! I'm just a language model, so I don't have feelings or emotions like humans do, but I'm functioning properly and ready to help you with any questions or tasks you may have. How can I assist you today?", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 48, 'prompt_tokens': 41, 'total_tokens': 89, 'completion_time': 0.122137721, 'completion_tokens_details': None, 'prompt_time': 0.002205197, 'prompt_tokens_details': None, 'queue_time': 0.161071164, 'total_time': 0.124342918}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_3272ea2d91', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019eb5c6-ee72-78a3-92b9-c400b2e04928-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 41, 'output_tokens': 48, 'total_tokens': 89})

# %% [markdown]
# ### Streaming
# Streaming means data is not shown when its completely produced it shows output chunks as soon as they are produced. So, its better for user experience during longer responses.

# %% [markdown]
# model.stream()  this is how you use stream function.

# %%
for chunk in model.stream("why do parrots have colorful feathers?"):
    print(chunk.text, end="", flush=True)
# Out:
# Parrots have colorful feathers for several reasons, including:
#
# 1. **Mating and Courtship**: Bright, vibrant feathers can be an attractive feature for potential mates. Parrots use their colorful plumage to signal their health, genetic quality, and suitability as a partner. Males, in particular, will often display their brightest feathers to impress females and establish dominance.
# 2. **Territorial Defense**: Colorful feathers can serve as a warning signal to other parrots, indicating that a particular territory is already occupied. This can help deter potential intruders and reduce the risk of conflict.
# 3. **Communication**: Parrots use their feathers to convey information and express emotions. For example, a parrot may raise its brightly colored feathers to signal excitement, alarm, or aggression.
# ...

# %% [markdown]
# ### Batching

# %% [markdown]
# Batching a collection of independent requests to a model can signifcantly improve its performance and reduce costs, as the processing can be done in parallel.

# %%
responses=model.batch([
    "Why do parrots have colorful feathers?",
    "How do airplanes fly?",
    "What is quantum computing?"
],
config={
    'max_concurrency': 5, #limit to 5 parallel cells
})
for response in responses:
    print(response)
# Out:
# content="Parrots have colorful feathers for several reasons, and these vibrant colors play a crucial role in their survival, communication, and social behavior. Here are some of the main reasons why parrots have colorful feathers:\n\n1. **Mating and Courtship**: Bright colors help parrots attract a mate. The more vibrant and intense the colors, the more attractive the parrot is to potential partners. This is especially true for male parrots, which often display their brightest colors during courtship rituals.\n2. **Communication and Social Status**: Colorful feathers help parrots convey information about their identity, age, sex, and social status. Different colors can signal dominance, submission, or friendship, allowing parrots to navigate their social hierarchies.\n3. **Camouflage and Warning Signals**: While it may seem counterintuitive, some parrots' bright colors serve as a warning to predators. For example, the bright colors of the poison dart frog-like parrots (e.g., the Lila
# ...
